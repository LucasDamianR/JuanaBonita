# %%
import pandas as pd
import pyodbc
import datetime
import numpy as np

# %%
server = 'tcp:192.168.1.6'
database ="planeamiento"
username = 'sa'
password = 'sa' 
cnxn = pyodbc.connect('DRIVER={/opt/microsoft/msodbcsql17/lib64/libmsodbcsql-17.2.so.0.1};SERVER='+server+
                      ';DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
fecha_alta = datetime.date.today()

# %%
cursor = cnxn.cursor()
try:
    cursor.execute(" UPDATE sc3_detalle SET tipo_es = (UPPER(tipo_es)) ")
    cnxn.commit()
except:
    print("Error en update")


cursor = cnxn.cursor()
try:
    cursor.execute(" UPDATE sc3_detalle SET color_es = (UPPER(color_es)) ")
    cnxn.commit()
except:
    print("Error en update")

# %%
try:
    cursor.execute(''' UPDATE sc3_detalle SET tipo_es = 'BLAZER' 
                       WHERE tipo_es = 'BLAZERS' 
                       
                       UPDATE sc3_detalle SET tipo_es = 'BLUSA' 
                       WHERE tipo_es = 'BLUSAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'BODY' 
                       WHERE tipo_es = 'BODY''S ' or tipo_es = 'BODYS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'BLUSA' 
                       WHERE tipo_es = 'BLUSAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'BLUSA' 
                       WHERE tipo_es = 'BLUSAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'BOMBACHA'
                       WHERE tipo_es = 'BOMBACHAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'BUZO'
                       WHERE tipo_es = 'BUZOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'CALZA'
                       WHERE tipo_es = 'CALZAS'                       
                       
                       UPDATE sc3_detalle SET tipo_es = 'CAMISA'
                       WHERE tipo_es = 'CAMISAS'
                                              
                       UPDATE sc3_detalle SET tipo_es = 'CAMPERA'
                       WHERE tipo_es = 'CAMPERAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'CARDIGAN'
                       WHERE tipo_es = 'CARDIGANS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'PANTALON'
                       WHERE tipo_es = 'CASUAL' or tipo_es = 'PANTALÓN' or tipo_es = 'PANTALONES'
                       
                       
                       UPDATE sc3_detalle SET tipo_es = 'CHALECO'
                       WHERE tipo_es = 'CHALECOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'CHAQUETA'
                       WHERE tipo_es = 'CHAQUETAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'CONJUNTO'
                       WHERE tipo_es = 'CONJUNTOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'FALDA'
                       WHERE tipo_es = 'FALDAS'
                       
                       
                       UPDATE sc3_detalle SET tipo_es = 'CONJUNTO'
                       WHERE tipo_es = 'CONJUNTOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'FALDA'
                       WHERE tipo_es = 'FALDAS'
                                              
                       UPDATE sc3_detalle SET tipo_es = 'JEAN'
                       WHERE tipo_es = 'JEANS'                       
                       
                       UPDATE sc3_detalle SET tipo_es = 'KIMONO'
                       WHERE tipo_es = 'KIMONOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'LENCERIA'
                       WHERE tipo_es = 'LENCERÍA'
                       
                       UPDATE sc3_detalle SET tipo_es = 'MONO'
                       WHERE tipo_es = 'MONOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'MUSCULOSA'
                       WHERE tipo_es = 'MUSCULOSAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'REMERA'
                       WHERE tipo_es = 'REMERAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'SACO'
                       WHERE tipo_es = 'SACÓN' or tipo_es = 'SACOS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'SHORT'
                       WHERE tipo_es = 'SHORTS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'SOUTIEN'
                       WHERE tipo_es = 'SOUTIENS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'SWEATER'
                       WHERE tipo_es = 'SWEATERS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'TOP'
                       WHERE tipo_es = 'TOPS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'T-SHIRT'
                       WHERE tipo_es = 'REMERA'
                       
                       UPDATE sc3_detalle SET tipo_es = 'TUNICA'
                       WHERE tipo_es = 'TÚNICA' or tipo_es = 'TÚNICAS'
                       
                       UPDATE sc3_detalle SET tipo_es = 'VESTIDO'
                       WHERE tipo_es = 'VESTIDOS' 
                       
                       
    ''')
    cnxn.commit()
except:
    print("Error en update")

# %%
uruguay = f"select * from sc3_detalle where origen like '%UY'"
uruguay = pd.read_sql(uruguay,cnxn)

# %%
len(uruguay)
#117526
# Out:
# 129713

# %%
uruguay.loc[uruguay['tipo_juana'] == 'nan','tipo_juana'] = np.nan

# %%
uruguay.loc[uruguay['grupo'] == 'nan','grupo'] = np.nan

# %%
uruguay[uruguay['tipo_juana'].isna() == True]
# Out:
#        id_sc3_producto  id_sc3_corrida       marca           tipo  \
# 16                P003               3       COCOT        Pijamas
# 17                P005               3       COCOT        Pijamas
# 18                P004               3       COCOT        Pijamas
# 19               YA132               3       COCOT        Pijamas
# 20                P002               3       COCOT        Pijamas
# 21              02-03B               3       COCOT        Pijamas
# 22                11-3               3       COCOT        Pijamas
# 23                P025               3       COCOT        Pijamas
# 24               P026B               3       COCOT        Pijamas
# 25               P027B               3       COCOT        Pijamas
# 26                P010               3       COCOT        Pijamas
# 27                P011               3       COCOT        Pijamas
# 28                 832               3       COCOT        Pijamas
# ...

# %%
uruguay[uruguay['grupo'].isna() == True]
# Out:
#        id_sc3_producto  id_sc3_corrida       marca           tipo  \
# 16                P003               3       COCOT        Pijamas
# 17                P005               3       COCOT        Pijamas
# 18                P004               3       COCOT        Pijamas
# 19               YA132               3       COCOT        Pijamas
# 20                P002               3       COCOT        Pijamas
# 21              02-03B               3       COCOT        Pijamas
# 22                11-3               3       COCOT        Pijamas
# 23                P025               3       COCOT        Pijamas
# 24               P026B               3       COCOT        Pijamas
# 25               P027B               3       COCOT        Pijamas
# 26                P010               3       COCOT        Pijamas
# 27                P011               3       COCOT        Pijamas
# 28                 832               3       COCOT        Pijamas
# ...

# %%
uruguay[(uruguay['tipo_juana'] == np.nan)&
       (uruguay['grupo'].isna() != True)]
# Out:
# Empty DataFrame
# Columns: [id_sc3_producto, id_sc3_corrida, marca, tipo, tipo_es, color, color_es, sexo, descripcion, moneda, precio, precio_original, fecha_alta, url_imagen, url_producto, origen, tipo_juana, grupo]
# Index: []

# %%
uruguay

# %%
g = uruguay.groupby(['id_sc3_producto','marca','tipo_es','color_es'])

# %%
L = []
NaN = []
for i in g:
    if len(i[1]['grupo'].unique())>1:
        
        GRUPO = i[1][i[1]['grupo'].isna()!=True]['grupo'].unique()
        if len(GRUPO) > 0:
            GRUPO = GRUPO[0]
        TIPO_JUANA = i[1][i[1]['tipo_juana'].isna()!=True]['tipo_juana'].unique()
        if len(TIPO_JUANA) > 0:
            TIPO_JUANA = TIPO_JUANA[0]
        if len(GRUPO)>0 and len(TIPO_JUANA)>0:
            
            L.append([i[1],GRUPO,TIPO_JUANA])
        else:
            NaN.append([i[1],GRUPO,TIPO_JUANA])

# %%
#tipo_juana
#grupo

# %%
cursor = cnxn.cursor()
for item in L:
    
    id_sc3_producto = item[0]['id_sc3_producto'].unique()[0]
    color_es = item[0]['color'].unique()[0]
    tipo_es = item[0]['tipo_es'].unique()[0]
        
    try:
        cursor.execute(f''' 
                UPDATE sc3_detalle 
                SET grupo = '{item[1]}',
                tipo_juana = '{item[2]}'
                
                where tipo_es = '{tipo_es}' 
                and color_es = '{color_es}'
                and id_sc3_producto = '{id_sc3_producto}'

                ''')
        cnxn.commit()
    except:
        print("Error en update")

# %%
uruguay = f"select * from sc3_detalle where origen like '%UY'"
uruguay = pd.read_sql(uruguay,cnxn)

# %%
g = uruguay.groupby(['id_sc3_producto','marca','tipo_es','color_es'])

# %%
REPE = []
for grupos in g['grupo']:
    if len(grupos[1].unique() != 1):
        REPE.append(grupos)
    break

# %%
grupos
# Out:
# (('02-03', 'COCOT', 'LENCERIA', 'AMARILLO'), 87512    LENCERIA
#  Name: grupo, dtype: object)

# %%
for index,row in uruguay.iterrows():
    
    if pd.isna(row['grupo']) == True:
        
        AUX = uruguay[
            (uruguay['id_sc3_producto']==row['id_sc3_producto'])&
            (uruguay['marca']==row['marca'])&
            (uruguay['tipo_es']==row['tipo_es'])&
            (uruguay['color_es']==row['color_es'])&
            (uruguay['descripcion']==row['descripcion'])
            ]
        GRUPO_AUX = AUX['grupo'].unique()[0]
        TIPO_JUANA_AUX = AUX['tipo_juana'].unique()[0]
        
        uruguay.loc[index,'grupo'] = GRUPO_AUX
        uruguay.loc[index,'tipo_juana'] = TIPO_JUANA_AUX

# %%
hoy = uruguay[uruguay['fecha_alta']==str(fecha_alta)]

# %%
cursor = cnxn.cursor()
try:
    cursor.execute(" UPDATE sc3_detalle SET tipo_es = (UPPER(tipo_es)) ")
    cnxn.commit()
except:
    print("Error en update")


cursor = cnxn.cursor()
try:
    cursor.execute(" UPDATE sc3_detalle SET color_es = (UPPER(color_es)) ")
    cnxn.commit()
except:
    print("Error en update")

# %%
database ="estimaciones"
username = 'sa'
password = 'sa' 
cnxn = pyodbc.connect('DRIVER={/opt/microsoft/msodbcsql17/lib64/libmsodbcsql-17.2.so.0.1};SERVER='+server+
                      ';DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
TIPOLOGIA_JB = "select nombre  from tipos"
TIPOLOGIA_JB = pd.read_sql(TIPOLOGIA_JB,cnxn)

# %%
inserts = uruguay[uruguay['tipo_juana'].isnull() ==True]

# %%
kern

# %%
#uruguay['TIPOLOGIA_JB'] = ""

# %%
inserts.loc[inserts['tipo_es']=='Babuchas','tipo_juana'] ='PANTALON'
# Out:
# /home/aa/miniconda3/envs/dev_env/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
TIPO_UNIQUE = inserts['tipo_es'].unique()

# %%
TIPO_UNIQUE
# Out:
# array(['ROPA INTERIOR', 'SHORT', 'BABUCHAS', 'MUSCULOSA', 'T-SHIRT',
#        'TUNICA', 'CAMISA', 'SOUTIEN', 'TRAJES DE BAÑO', 'LENCERIA',
#        'BLUSA', 'BOMBACHA', 'MALLAS', 'CHAQUETA', 'SWEATER', 'TAPADOS',
#        'BERMUDA', 'ENTERITOS', 'CONJUNTO', 'FALDA', 'TOP', 'TRAJE',
#        'CAMISONES', 'KIMONO', 'MONO', 'VESTIDO', 'DEPORTIVO', 'PANTALON',
#        'MEDIAS', 'PIJAMAS', 'CARDIGAN', 'RUANA', 'BODY', 'BUZO',
#        'ROPA DE DORMIR', 'JEAN', 'CAMPERA', 'VESTIMENTA', 'BABY DOLLS',
#        'SACO', 'BOXERS', 'SOBRETODO', 'SUDADERAS', 'PILOTS', 'POLERAS',
#        'BLAZER', 'CALZA', 'CAFTAN', 'PALAZZO', 'CULOTTE', 'CAPRI',
#        'CHALECO', 'LEGGING', 'ROPA DEPORTIVA', 'BERMUDAS Y SHORTS',
#        'MANGA CORTA', 'BLUSAS Y CAMISETAS', 'CAMISETAS', 'CALZONCILLOS'],
#       dtype=object)

# %%
for index,row in inserts.iterrows():
    
    if row['descripcion'].upper().find('TOP') != -1 or row['descripcion'].upper().find('TOPS') != -1:
        inserts.loc[index,'tipo_juana'] = 'TOP'
    if row['descripcion'].upper().find('BIKINI') != -1 or row['descripcion'].upper().find('BIKINIS') != -1 or row['descripcion'].upper().find('BIQUINI') != -1:
        inserts.loc[index,'tipo_juana'] = 'BIKINI'
    if row['descripcion'].upper().find('COLALESS') != -1 or row['descripcion'].upper().find('COLA LESS') != -1:
        inserts.loc[index,'tipo_juana'] = 'COLA LESS'
    if row['descripcion'].upper().find('BONBACHA') != -1 or row['descripcion'].upper().find('BOMBACHA') != -1 or row['descripcion'].upper().find('BOKINI') != -1:
        inserts.loc[index,'tipo_juana'] = 'BOMBACHA'
    if row['descripcion'].upper().find('CAMISETA') != -1 or row['descripcion'].upper().find('CAMISETAMASCULINA') != -1:
        inserts.loc[index,'tipo_juana'] = 'CAMISETA'
    if row['descripcion'].upper().find('CAMISÓN') != -1 or row['descripcion'].upper().find('CAMISON') != -1: 
        inserts.loc[index,'tipo_juana'] = 'CAMISON' 
    if row['descripcion'].upper().find('CULOTTE') != -1 or row['descripcion'].upper().find('COULOTTE') != -1 or row['descripcion'].upper().find('CULOTE') != -1:
        inserts.loc[index,'tipo_juana'] = 'CULOTTE' 
    if row['descripcion'].upper().find('VEDETINA') != -1:
        inserts.loc[index,'tipo_juana'] = 'VEDETINA'
    if row['descripcion'].upper().find('TANGA') != -1:
        inserts.loc[index,'tipo_juana'] = 'TANGA'
    if row['descripcion'].upper().find('BERMUDA') != -1:
        inserts.loc[index,'tipo_juana'] = 'BERMUDA'
    if row['descripcion'].upper().find('TRIANGULO') != -1 or row['descripcion'].upper().find('TRIÁNGULO') != -1:
        inserts.loc[index,'tipo_juana'] = 'TRIANGULITO'
    if row['descripcion'].upper().find('BLASER') != -1 or row['descripcion'].upper().find('BLAZER') != -1 or row['descripcion'].upper().find('BLAIZER') != -1 or row['descripcion'].upper().find('BLAISER') != -1:
        inserts.loc[index,'tipo_juana'] = 'BLAZER'
    if row['descripcion'].upper().find('PANTALON') != -1 or row['descripcion'].upper().find('PANTALÓN') != -1 or row['descripcion'].upper().find('PALAZZO') != -1:
        inserts.loc[index,'tipo_juana'] = 'PANTALON' 
    if row['descripcion'].upper().find('PUSH UP') != -1 or row['descripcion'].upper().find('PUSH-UP') != -1: 
        inserts.loc[index,'tipo_juana'] = 'PUSH UP'
    if row['descripcion'].upper().find('STRAPLESS') != -1:
        inserts.loc[index,'tipo_juana'] = 'STRAPLESS'
    if row['descripcion'].upper().find('MUSCULOSA') != -1 or row['descripcion'].upper().find('MUSCOLOSA') != -1 or row['descripcion'].upper().find('MUSCULOS') != -1:
        inserts.loc[index,'tipo_juana'] = 'MUSCULOSA'
    if row['descripcion'].upper().find('KIMONO') != -1 or row['descripcion'].upper().find('SACO') != -1:
        inserts.loc[index,'tipo_juana'] = 'SACO'
    if row['descripcion'].upper().find('FALDA') != -1 or row['descripcion'].upper().find('SKIRT') != -1 or row['descripcion'].upper().find('POLLERA') != -1:
        inserts.loc[index,'tipo_juana'] = 'POLLERA'
    if row['descripcion'].upper().find('CORSET') != -1:
        inserts.loc[index,'tipo_juana'] = 'CORSET'
    if row['descripcion'].upper().find('BABUCHA') != -1 or row['descripcion'].upper().find('PANTELÓN') != -1:
        inserts.loc[index,'tipo_juana'] = 'PANTALON' 
    if row['descripcion'].upper().find('BLUSA') != -1 or row['descripcion'].upper().find('BLUSÓN') != -1:
        inserts.loc[index,'tipo_juana'] = 'BLUSA'
    if row['descripcion'].upper().find('BATA') != -1:
        inserts.loc[index,'tipo_juana'] = 'BATA'
    if row['descripcion'].upper().find('SWEATER') != -1:
        inserts.loc[index,'tipo_juana'] = 'SWEATER'
    if row['descripcion'].upper().find('CHALECO') != -1:
        inserts.loc[index,'tipo_juana'] = 'CHALECO' 
    if row['descripcion'].upper().find('CALZA') != -1 or row['descripcion'].upper().find('LEGGINGS') != -1 or row['descripcion'].upper().find('LEGGING') != -1:
        inserts.loc[index,'tipo_juana'] = 'CALZA'
    if row['descripcion'].upper().find('MALLA') != -1 or row['descripcion'].upper().find('MALLAS') != -1:
        inserts.loc[index,'tipo_juana'] = 'MALLA'
    if row['descripcion'].upper().find('CAMPERA') != -1:
        inserts.loc[index,'tipo_juana'] = 'CAMPERA'
    if row['descripcion'].upper().find('CARDIGAN') != -1 or row['descripcion'].upper().find('SACÓN') != -1 or row['descripcion'].upper().find('CÁRDIGAN') != -1:
        inserts.loc[index,'tipo_juana'] = 'SACO' 
    if row['descripcion'].upper().find('SACO') != -1 or row['descripcion'].upper().find('ZACO') != -1:
        inserts.loc[index,'tipo_juana'] = 'SACO'
    if row['descripcion'].upper().find('BOXER') != -1 or row['descripcion'].upper().find('BÓXER') != -1 or row['descripcion'].upper().find('BOMXER') != -1:
        inserts.loc[index,'tipo_juana'] = 'BOXER'
    if row['descripcion'].upper().find('JEAN') != -1 or row['descripcion'].upper().find('JEANS') != -1:
        inserts.loc[index,'tipo_juana'] = 'JEAN'
    if row['descripcion'].upper().find('TANK') != -1 or row['descripcion'].upper().find('TANKINI') != -1 or row['descripcion'].upper().find('MUSCULOS') != -1:
        inserts.loc[index,'tipo_juana'] = 'MUSCULOSA'
    if row['descripcion'].upper().find('SLIP') != -1:
        inserts.loc[index,'tipo_juana'] = 'SLIP'
    if row['descripcion'].upper().find('MONTGOMERY') != -1:
        inserts.loc[index,'tipo_juana'] = 'TAPADO'
    if row['descripcion'].upper().find('CHAQUETA') != -1 or row['descripcion'].upper().find('JACKET') != -1:
        inserts.loc[index,'tipo_juana'] = 'CHAQUETA'
    if row['descripcion'].upper().find('VESTIDO') != -1 or row['descripcion'].upper().find('SOLERA') != -1:
        inserts.loc[index,'tipo_juana'] = 'VESTIDO'
    if row['descripcion'].upper().find('TRUSA') != -1:
        inserts.loc[index,'tipo_juana'] = 'TRUSA'
    if row['descripcion'].upper().find('TÚNICA') != -1 or row['descripcion'].upper().find('CAMISOLA') != -1:
        inserts.loc[index,'tipo_juana'] = 'CAMISOLA'
    if row['descripcion'].upper().find('MONO') != -1 or row['descripcion'].upper().find('ENTERITO') != -1:
        inserts.loc[index,'tipo_juana'] = 'ENTERITO'
    if row['descripcion'].upper().find('CAMISOLÍN') != -1 or row['descripcion'].upper().find('CAMISOLIN') != -1:
        inserts.loc[index,'tipo_juana'] = 'CAMISOLIN'
    if row['descripcion'].upper().find('BUZO') != -1 or row['descripcion'].upper().find('SUDADERA') != -1:
        inserts.loc[index,'tipo_juana'] = 'BUZO' 
    if row['descripcion'].upper().find('PONCHO') != -1:
        inserts.loc[index,'tipo_juana'] = 'PONCHO'
    if row['descripcion'].upper().find('BODY') != -1:
        inserts.loc[index,'tipo_juana'] = 'BODY'        
    if row['descripcion'].upper().find('REMERA') != -1 or row['descripcion'].upper().find('T-SHIRT') != -1:
        inserts.loc[index,'tipo_juana'] = 'REMERA'        
    if row['descripcion'].upper().find('EXTENSOR') != -1:
        inserts.loc[index,'tipo_juana'] = 'EXTENSORES'
    if row['descripcion'].upper().find('SHORT') != -1:
        inserts.loc[index,'tipo_juana'] = 'SHORT'
    if row['descripcion'].upper().find('CAMISA') != -1:
        inserts.loc[index,'tipo_juana'] = 'CAMISA'
    if row['descripcion'].upper().find('CON ARO') != -1 or row['descripcion'].upper().find('C/ARO') != -1:
        inserts.loc[index,'tipo_juana'] = 'CON ARCO' 
    if row['descripcion'].upper().find('CONJUNTO') != -1:
        inserts.loc[index,'tipo_juana'] = 'CONJUNTO'    
    if row['descripcion'].upper().find('REDUCTOR') != -1:
        inserts.loc[index,'tipo_juana'] = 'REDUCTOR'    
    if row['descripcion'].upper().find('SIN ARO') != -1:
        inserts.loc[index,'tipo_juana'] = 'SIN ARCO'    
    if row['descripcion'].upper().find('POLERA') != -1:
        inserts.loc[index,'tipo_juana'] = 'POLERA'

# %%
for index,row in inserts.iterrows():
    if row['tipo_juana'] == None:
        if row['tipo'].upper().find("TÚNICAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'CAMISOLA'
        if row['tipo'].upper().find("JEGGING") != -1:
            inserts.loc[index,'tipo_juana'] = 'JEAN'
        if row['tipo'].upper().find("POLO") != -1:
            inserts.loc[index,'tipo_juana'] = 'CHOMBA'
        if row['tipo'].upper().find("TUNICA") != -1 or row['tipo'].upper().find("TÚNICAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'CAMISOLA'
        if row['tipo'].upper().find("CAMISAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'CAMISA'
        if row['tipo'].upper().find("CALZONCILLOS") != -1:
            inserts.loc[index,'tipo_juana'] = 'BOXER'
        if row['tipo'].upper().find("CAMPERAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'CAMPERA'
        if row['tipo'].upper().find("MANGA CORTA") != -1:
            inserts.loc[index,'tipo_juana'] = 'REMERA'
        if row['tipo'].upper().find("JEANS") != -1:
            inserts.loc[index,'tipo_juana'] = 'JEAN'
        if row['tipo'].upper().find("MALLAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'MALLA'
        if row['tipo'].upper().find("POLERAS") != -1:
            inserts.loc[index,'tipo_juana'] = 'POLERA'
        if row['descripcion'].upper().find('POLO') != -1:
            inserts.loc[index,'tipo_juana'] = 'CHOMBA'

# %%
len(inserts)
# Out:
# 7534

# %%
inserts[inserts['tipo_juana'].isnull() == True]
# Out:
#      id_sc3_producto  id_sc3_corrida  marca           tipo        tipo_es  \
# 19          Silicona               6  COCOT       Soutiens       SOUTIENS
# 21             YA073               6  COCOT       Soutiens       SOUTIENS
# 22             YA034               6  COCOT       Soutiens       SOUTIENS
# 23               924               6  COCOT       Soutiens       SOUTIENS
# 26              5782               6  COCOT       Soutiens       SOUTIENS
# 50              5636               6  COCOT       Soutiens       SOUTIENS
# 51            FE-324               6  COCOT      Bombachas      BOMBACHAS
# 54        MJPTY34386               6  COCOT      Bombachas      BOMBACHAS
# 55              S313               6  COCOT       Soutiens       SOUTIENS
# 57               684               6  COCOT       Soutiens       SOUTIENS
# 63              5636               6  COCOT       Soutiens       SOUTIENS
# 68              5477               6  COCOT       Soutiens       SOUTIENS
# ...

# %%
INSERT = uruguay[uruguay['TIPOLOGIA_JB']!= ""].copy()

# %%
cursor = cnxn.cursor()
excepts = []
for index,row in INSERT.iterrows():  
    tipo = row['TIPOLOGIA_JB']
    id_ = row['id_sc3_producto']
    color = row['color']
    tipo_es = row['tipo_es']
    marca = row['marca']
    try:
        cursor.execute(f""" 
            UPDATE sc3_detalle SET tipo_juana = '{tipo}' 
            where id_sc3_producto = '{id_}' and color_es = '{color}' and marca = '{marca}' and tipo_es = '{tipo_es}' """)
        cnxn.commit()
    except:
        excepts.append(row)
#cursor.close()
#cnxn.close()

# %%
(f'''
UPDATE sc3_detalle SET tipo_juana = '{tipo}' where id_sc3_producto = '{id_}' and color_es = '{color}' and marca = '{marca}' and tipo_es = '{tipo_es}'                                              
''')
# Out:
# "\nUPDATE sc3_detalle SET tipo_juana = 'BODY' where id_sc3_producto = '1308186' and color_es = 'Estampado' and marca = 'INDIAN' and tipo_es = 'Body's'                                              \n"

# %%
index
# Out:
# 18918

# %%
INSERT = INSERT.loc[15906:].copy().reset_index(drop=True)

# %%
asd = pd.read_excel("TIPO_JUANA.xlsx")

# %%
asd
# Out:
#       id_sc3_producto  id_sc3_corrida          marca     tipo  tipo_es  \
# 0                P003               3          COCOT  Pijamas  PIJAMAS
# 1                P005               3          COCOT  Pijamas  PIJAMAS
# 2                P004               3          COCOT  Pijamas  PIJAMAS
# 3               YA132               3          COCOT  Pijamas  PIJAMAS
# 4                P002               3          COCOT  Pijamas  PIJAMAS
# 5              02-03B               3          COCOT  Pijamas  PIJAMAS
# 6                11-3               3          COCOT  Pijamas  PIJAMAS
# 7                P025               3          COCOT  Pijamas  PIJAMAS
# 8               P026B               3          COCOT  Pijamas  PIJAMAS
# 9               P027B               3          COCOT  Pijamas  PIJAMAS
# 10               P010               3          COCOT  Pijamas  PIJAMAS
# 11               P011               3          COCOT  Pijamas  PIJAMAS
# ...

# %%
Test = pd.merge(uruguay,asd,on=['id_sc3_producto','marca','tipo_es','color_es'],how='left')[['id_sc3_producto','marca','tipo_es','color_es','GRUPO','TIPO JUANA','descripcion_x']]

# %%
Test[(Test['id_sc3_producto'] == '02-03B') & (Test['tipo_es'] == 'LENCERIA') & (Test['color_es']=='AMARILLO')]
# Out:
#       id_sc3_producto  marca   tipo_es  color_es     GRUPO TIPO JUANA  \
# 15606          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 15607          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 15608          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 74646          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 74647          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 74648          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 75961          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 75962          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
# 75963          02-03B  COCOT  LENCERIA  AMARILLO  LENCERIA     PIJAMA
#
#                     descripcion_x
# 15606  Pijama a lunares plus size
# 15607  Pijama a lunares plus size
# 15608  Pijama a lunares plus size
# 74646  Pijama a lunares plus size
# 74647  Pijama a lunares plus size
# 74648  Pijama a lunares plus size
# ...

# %%
Test.head()
# Out:
#   id_sc3_producto marca        tipo_es      color_es GRUPO       TIPO JUANA  \
# 0            8218  SISI  ROPA INTERIOR          AZUL   TDB  CONJUNTO BIKINI
# 1            8218  SISI  ROPA INTERIOR          AZUL   TDB  CONJUNTO BIKINI
# 2            8218  SISI  ROPA INTERIOR          AZUL   TDB  CONJUNTO BIKINI
# 3            8218  SISI  ROPA INTERIOR  ROSA ANTIQUE   TDB  CONJUNTO BIKINI
# 4            8218  SISI  ROPA INTERIOR  ROSA ANTIQUE   TDB  CONJUNTO BIKINI
#
#           descripcion_x
# 0  Bikini de microfibra
# 1  Bikini de microfibra
# 2  Bikini de microfibra
# 3  Bikini de microfibra
# 4  Bikini de microfibra

# %%
cursor = cnxn.cursor()
excepts = []
for index,row in Test.iterrows():  
    tipo = row['TIPO JUANA']
    id_ = row['id_sc3_producto']
    color_es = row['color_es']
    tipo_es = row['tipo_es']
    marca = row['marca']
    grupo = row['GRUPO']
    try:
        cursor.execute(f""" 
            UPDATE sc3_detalle SET tipo_juana = '{tipo}' , grupo = '{grupo}'
            where id_sc3_producto = '{id_}' and color_es = '{color_es}' and marca = '{marca}' and tipo_es = '{tipo_es}' """)
        cnxn.commit()
    except:
        excepts.append(row)
#cursor.close()
#cnxn.close()

# %%
excepts
# Out:
# []

# %%
uruguay[uruguay['TIPOLOGIA_JB'] == '']['tipo'].unique()
# Out:
# array(['Ropa interior', 'Ropa de dormir', 'Pijamas', 'Bombachas',
#        'Trajes de baño', 'SOBRETODO', 'TRAJE', 'Lencería', 'Ruana',
#        'Soutiens', 'Cazadora', 'Vestimenta', 'Soutien', 'Camisetas',
#        'SOUTIEN', 'Medias', 'FITNESS', 'SOUTIENS', 'Pilots'], dtype=object)

# %%
uruguay[(uruguay['TIPOLOGIA_JB'] == '')&(uruguay['tipo']=='Ropa interior')]['tipo'].unique()
# Out:
# array(['Ropa interior', 'Ropa de dormir', 'Pijamas', 'Bombachas',
#        'Trajes de baño', 'SOBRETODO', 'TRAJE', 'Lencería', 'Ruana',
#        'Soutiens', 'Cazadora', 'Vestimenta', 'Soutien', 'Camisetas',
#        'SOUTIEN', 'Medias', 'FITNESS', 'SOUTIENS', 'Pilots'], dtype=object)

# %%
uruguay[(uruguay['TIPOLOGIA_JB'] == '')&(uruguay['tipo']=='Ropa interior')]['descripcion'].unique()
# Out:
# array(['Soutiene preformado de microfibra', 'Bolsa para lavado',
#        'Breteles de silicona', 'Hebillas para breteles',
#        'Soutien marylin puntilla bicolor', 'Corpiño puntilla plus malbec',
#        'Faja alta', 'Soutien juvenil', 'Soutien de silicona cocot',
#        'Soutien grande bordado', 'Soutien algodón prendido delante',
#        'Soutien con espalda de silicona', 'Corpiño armado segunda piel',
#        'Bralette con puntilla', 'Soutien preformado joy',
#        'Pack x2 soutien preformado de microfibra',
#        'Soutien preformado copa d',
#        'Soutien preformado microfibra 2 breteles',
#        'Soutiene de bretel fino con copa',
#        'Soutien preformado de modal con puntilla',
#        'Porta liga con puntilla de flores',
#        'Soutien preformado con puntilla de flores copa c',
#        'Soutien preformado con puntilla de flores',
#        'Soutien preformado de algodón y lycra estampado roxana',
#        'Soutien preformado de microfibra rocio',
# ...

# %%
len(uruguay)
# Out:
# 38380

# %%
uruguay.loc[31640]
# Out:
# id_sc3_producto                                              1308742
# id_sc3_corrida                                                     4
# marca                                                         INDIAN
# tipo                                                          Shorts
# tipo_es                                                       Shorts
# color                                                         Blanco
# color_es                                                      Blanco
# sexo                                                           Mujer
# descripcion                           Short fortunata 00809 - Blanco
# moneda                                                      PESOS UY
# precio                                                           899
# precio_original                                                  899
# fecha_alta                                       2019-11-12 00:00:00
# url_imagen         https://s.fenicio.app/f2/indiuy/catalogo/artic...
# ...
