# %%
 
# coding: utf-8

# In[2]:


from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import requests
from time import strftime
import datetime
import time
from pandas import ExcelWriter
import re
import pyodbc
from selenium.webdriver.common.action_chains import ActionChains
import numpy as np
from ipywidgets import IntProgress
from IPython.display import display
from IPython.display import clear_output
import itertools
import os


# In[3]:


scraper='COCOT'


# In[4]:


URLS = [['Mujer','https://cocot.com.uy/damas'],
        ['Hombre','https://cocot.com.uy/hombres']]


# In[5]:


start_ = datetime.datetime.now()
fecha = datetime.date.today()


user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'    

chrome_options = Options()  
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument(f'user-agent={user_agent}')
chrome_options.add_argument("--window-size=1325x1744")
browser = webdriver.Chrome('/usr/bin/chromedriver', options = chrome_options)
browser.delete_all_cookies()


# In[6]:

# %%
full_urls = []
for url in URLS:
    browser.get(url[1])
    
    labels = browser.execute_script("return document.getElementsByClassName('lst lstCtm')[0];").find_elements_by_tag_name('label')
    for item in labels:
        full_urls.append([url[0],
                          browser.current_url+f"?color={item.get_attribute('data-val')}",
                          item.get_attribute('data-val')
                         ])

# %%
items = []

for url in full_urls:

    browser.get(url[1])
    
    last_height = browser.execute_script("return document.body.scrollHeight")
    while True:

        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(6)
        try:
            browser.execute_script('window.scrollTo(0, 1100);')
            #browser.find_element_by_xpath('//*[@id="catalogoPaginado"]/button/span').click()
            browser.execute_script('window.scrollTo(0, 1500);')
            browser.find_element_by_id('catalogoPaginado').click()
        except:
            pass

        new_height = browser.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        
    page = BeautifulSoup(browser.page_source,"html.parser")
    #Descripcion
    DESC = [i['title'] for i in page.find_all(class_='img')]
    #href
    HREF = [i['href'] for i in page.find_all(class_='img')]
    #img
    IMG = [i.img['src'] for i in page.find_all(class_='img')]
    #ID
    aux_it = [i.find_all(class_='it') for i in page.find_all(id='catalogoProductos')][0]
    ID = [i['data-codprod'] for i in aux_it]
    PRECIO = [i.find_all(class_='precios')[0].text for i in aux_it]    
    
    z=[]
    for id,desc,img,precio,href in zip(ID,DESC,IMG,PRECIO,HREF):
        z.append([id,desc,url[0],url[2],img,precio,href])
    items.append(z)

# %%
items = list(itertools.chain(*items))

# %%
asd= pd.DataFrame(A)

# %%
len(items)
# Out:
# 21

# %%
asd
# Out:
#             0                                                  1       2  \
# 0       YA202                                              Nuevo   Mujer
# 1       ya231                                              Nuevo   Mujer
# 2        3816                                              Nuevo   Mujer
# 3        9031                                              Nuevo   Mujer
# 4      B11946                                              Nuevo   Mujer
# 5      1015DD                                              Nuevo   Mujer
# 6        1806                                              Nuevo   Mujer
# 7        2969                                              Nuevo   Mujer
# 8      3006-2                                              Nuevo   Mujer
# 9        3015                                              Nuevo   Mujer
# 10       3015                                              Nuevo   Mujer
# 11       3693                                              Nuevo   Mujer
# 12        701                                              Nuevo   Mujer
# 13      58179                        Malla Culotte de Baño negro   Mujer
# 14       9928                              Malla Estampada negro   Mujer
# 15      M1803                             Malla con Guarda negro   Mujer
# 16        103                                Body Reductor negro   Mujer
# 17      11382                            Malla de Natación negro   Mujer
# 18       2801                Malla de Natación Manga Larga negro   Mujer
# 19      YA218                             Trusa con Pierna negro   Mujer
# 20       5533    Top Reforzado Algodón Y Lycra sin Costura negro   Mujer
# 14     negro  //s.fenicio.app/f2/coc/productos/9928-negro_46...
# 15     negro  //s.fenicio.app/f2/coc/productos/m1803-negro_4...
# 16     negro  //s.fenicio.app/f2/coc/productos/103-negro_460...
# 17     negro  //s.fenicio.app/f2/coc/productos/11382-negro_4...
# 18     negro  //s.fenicio.app/f2/coc/productos/2801-negro_46...
# 19     negro  //s.fenicio.app/f2/coc/productos/ya218-negro_4...
# 20     negro  //s.fenicio.app/f2/coc/productos/5533_460x614_...
# 21     negro  //s.fenicio.app/f2/coc/productos/5547_460x614_...
# 22     negro  //s.fenicio.app/f2/coc/productos/5567_460x614_...
# 23     negro  //s.fenicio.app/f2/coc/productos/1-5571_460x61...
# 24     negro  //s.fenicio.app/f2/coc/productos/1-12703-negro...
# 25     negro  //s.fenicio.app/f2/coc/productos/12704-vichy_4...
# 26     negro  //s.fenicio.app/f2/coc/productos/12708-negro_4...
# 27     negro  //s.fenicio.app/f2/coc/productos/12712_460x614...
# 28     negro  //s.fenicio.app/f2/coc/productos/12714_460x614...
# 29     negro  //s.fenicio.app/f2/coc/productos/12715_460x614...
# ..       ...                                                ...
# 426     gris  //s.fenicio.app/f2/coc/productos/dsc-0446_460x...
# 427     gris  //s.fenicio.app/f2/coc/productos/3-dsc-0418_46...
# 428     gris  //s.fenicio.app/f2/coc/productos/1-p027b-celes...
# 429     gris  //s.fenicio.app/f2/coc/productos/170-gris_460x...
# 430     gris  //s.fenicio.app/f2/coc/productos/mamalaser193-...
# 431    negro  //s.fenicio.app/f2/coc/productos/11849_460x614...
# 432    negro  //s.fenicio.app/f2/coc/productos/1-ya113-a_460...
# 433    negro  //s.fenicio.app/f2/coc/productos/1192810web_46...
# 434    negro  //s.fenicio.app/f2/coc/productos/dlanegro_460x...
# 435    negro  //s.fenicio.app/f2/coc/productos/1-2556_460x61...
# 436    negro  //s.fenicio.app/f2/coc/productos/508-a_460x614...
# 437    negro  //s.fenicio.app/f2/coc/productos/1-509-a_460x6...
# 438    negro  //s.fenicio.app/f2/coc/productos/510-a_460x614...
# 439    negro  //s.fenicio.app/f2/coc/productos/imagenproduct...
# 440    negro  //s.fenicio.app/f2/coc/productos/2100-3-negro_...
# 441    negro  //s.fenicio.app/f2/coc/productos/2092-a-negro_...
# 442   blanco  //s.fenicio.app/f2/coc/productos/ya216_460x614...
# 443    verde  //s.fenicio.app/f2/coc/productos/1801-amarillo...
# 444     azul  //s.fenicio.app/f2/coc/productos/645-azul_460x...
# 445     azul  //s.fenicio.app/f2/coc/productos/1801-azul_460...
# 446  celeste  //s.fenicio.app/f2/coc/productos/645-celeste_4...
# 447  celeste  //s.fenicio.app/f2/coc/productos/1-748-celeste...
# 448  celeste  //s.fenicio.app/f2/coc/productos/1-748-gris_46...
# 449     gris  //s.fenicio.app/f2/coc/productos/2-748-gris_46...
# 450     gris  //s.fenicio.app/f2/coc/productos/748-gris_460x...
# 451     gris  //s.fenicio.app/f2/coc/productos/743-gris-clar...
# 452     gris  //s.fenicio.app/f2/coc/productos/18401_460x614...
# 453     gris  //s.fenicio.app/f2/coc/productos/1-18401_460x6...
# 454     gris  //s.fenicio.app/f2/coc/productos/1-ya042_460x6...
# 439         $ 179   https://cocot.com.uy/catalogo/media-elegance-l...
# 440         $ 270   https://cocot.com.uy/catalogo/medias-crew-depo...
# 441         $ 179   https://cocot.com.uy/catalogo/media-supplex-el...
# 442         $ 199   https://cocot.com.uy/catalogo/camisilla_YA216_...
# 443         $ 290   https://cocot.com.uy/catalogo/short-estampado-...
# 444         $ 290   https://cocot.com.uy/catalogo/short-de-bano-az...
# 445         $ 290   https://cocot.com.uy/catalogo/short-estampado-...
# 446         $ 290   https://cocot.com.uy/catalogo/short-de-bano-ce...
# 447         $ 990   https://cocot.com.uy/catalogo/pijama-abotonado...
# 448         $ 879   https://cocot.com.uy/catalogo/pijama-abotonado...
# 449         $ 990   https://cocot.com.uy/catalogo/pijama-abotonado...
# 450         $ 879   https://cocot.com.uy/catalogo/pijama-abotonado...
# 451       $ 1.150   https://cocot.com.uy/catalogo/pijama-de-hombre...
# 452         $ 390   https://cocot.com.uy/catalogo/boxer-largo-grue...
# 453         $ 390   https://cocot.com.uy/catalogo/boxer-largo-grue...
# 454         $ 290   https://cocot.com.uy/catalogo/boxer-largo-fino...
# 455         $ 890   https://cocot.com.uy/catalogo/boxer-largo-mela...
#
# [456 rows x 7 columns]

# %%
# Out:
# 60

# %%
Y = asd[(asd[3] =='negro') & (asd[2]=='Mujer')]

# %%
elementos_it = WebDriverWait(browser, 100).until(EC.presence_of_element_located((By.ID,'catalogoProductos'))).find_elements_by_class_name('it')

# %%
elementos_it
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ae0ce1f9141ec5044c2ae4ef1afff4e5", element="0.5230888932739746-8")>]

# %%
# Out:
# '748B'

# %%
#[ID,
#DESCRIPCION,
CATEGORIA[0],
#COLOR,
#url[0], **TIPO **
#PRECIO,
#HREF,
#IMG])

# %%
LISTA_PRODUCTOS = []
#browser.find_element_by_xpath('//*[@id="catalogoFiltros"]/div/div[1]/div[2]/div')
for url in full_urls:
    browser.get(url[1])
    BLK = browser.find_element_by_class_name('blk')
    if BLK.get_attribute('data-codigo') != 'categoria':
        raise "ERROR EN CATEGORÍA"

    #NAVEGAR POR EL ELEMENTO BLK HASTA LLEGAR A LA LISTA DONDE ESTAN
    #LAS LABELS 
    LABELS = BLK.find_element_by_class_name('lst').find_elements_by_tag_name('label')

    CATEGORIAS = []
    #QUITAR ELEMENTOS NO DESEADOS
    for i in LABELS:
        #CREAR UN STR DE MAYÚSCULAS 
        CAT = str(i.get_attribute('title')).upper()
        if  CAT == 'MEDIAS':
            continue
        elif CAT == 'ACCESORIOS':
            continue
        else:
            CATEGORIAS.append([CAT.capitalize(),i.get_attribute('data-val')])
    #ITERAR CATEGORIAS
    for CATEGORIA in CATEGORIAS:
        
        browser.get(CATEGORIA[1])
        
        SUB_CATEGORIAS = []
        
        #GUARDO LA PÁGINA PARA HACER UNA REQUEST AL FINALIZAR TODOS LOS COLORES
        CURRENT_URL = browser.current_url
        #LABELS CATEGORIA DONDE SE GUARDAN TODAS LAS CATEGORÍAS
        try:
            LABELS_CATEGORIA = browser.find_element_by_class_name('blk').find_element_by_class_name('lst').find_elements_by_tag_name('label')
            NO_HAY = 0
        except:
            NO_HAY = 1
        #SI NO_HAY ES 1 . (SIGNIFICA QUE NO TIENE SUB_CATEGORIA)
        if NO_HAY == 1 or CATEGORIA[0] == 'Ropa deportiva':
            
            try:                
                AUX_PALETA = browser.find_element_by_xpath('//*[@id="catalogoFiltros"]').find_element_by_class_name('cnt').find_elements_by_class_name('blk')[-1]
            except:
                continue
            #Si contiene 'Color' hicimos bien el trabajo, sino.. tendremos que revisar (si cambio el HTML)
            if 'Color' == AUX_PALETA.text:
                
                #LOOP de AUX_PALETA, cada elemento tiene el color. 
                PALETA = AUX_PALETA.find_elements_by_class_name('it')
                PALETA_COLORES = [[i,i.get_attribute('data-val')] for i in PALETA]
                #for COLOR_AUX in PALETA_COLORES:
                for i in range(1,len(PALETA_COLORES)+1):
                    #ESTOY POR ACA DPS SEGUIR VIENDO
                    for X in [9,8,4,5,6]:
                        try:
                            #Clickear color
                            #Cada nombre en Capitalize() porque es minúscula
                            NOMBRE_COLOR = browser.find_element_by_css_selector(f'#catalogoFiltros > div > div:nth-child({X}) > div.cnt > div > label:nth-child({i})').get_attribute('data-val')
                            #NOMBRE_COLOR = COLOR_AUX[1]
                            browser.find_element_by_css_selector(f'#catalogoFiltros > div > div:nth-child(9) > div.cnt > div > label:nth-child({i})').click()
                            break
                        except:
                            pass
                    time.sleep(1.5)
                    #requesst de la pagina actual
                    page = BeautifulSoup(browser.page_source,"html.parser")
                    
                    #A VER SI FUNCIONA AHORA ESTA PORQUERIA
                    browser.get(browser.current_url)
                    ##scroll 
                    last_height = browser.execute_script("return document.body.scrollHeight")
                    while True:

                        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                        time.sleep(5.5)
                        try:
                            browser.execute_script('window.scrollTo(0, 1100);')
                            #browser.find_element_by_xpath('//*[@id="catalogoPaginado"]/button/span').click()
                            browser.execute_script('window.scrollTo(0, 1500);')
                            browser.find_element_by_id('catalogoPaginado').click()
                        except:
                            pass
                            
                        new_height = browser.execute_script("return document.body.scrollHeight")
                        if new_height == last_height:
                            break
                        last_height = new_height
                    
                    page = BeautifulSoup(browser.page_source,"html.parser")
                    #VER SI AL FINALIZAR EL SCROLL, SE PUDO MOSTRAR TODOS LOS PRODUCTOS
                    try:
                        if int(browser.find_element_by_id("catalogoPaginado").text.split()[1]) != int(browser.find_element_by_id("catalogoPaginado").text.split()[-1]):

                            print(browser.find_element_by_id("catalogoPaginado").text)
                            browser.find_element_by_xpath('//*[@id="catalogoPaginado"]/button').click()
                    except:
                        pass
                    
                    #TODOS LOS PRODUCTOS
                    DIV_PRODUCTOS = browser.find_element_by_xpath('//*[@id="catalogoProductos"]').find_elements_by_class_name('it')
                    
                    for PRODUCTO in DIV_PRODUCTOS:
                        #EXCLUIR LAS IMAGENES PNG(NORMALMENTE SON ICONOS)
                        AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[0].get_attribute('src')
                        if AUX_JPG.find('.jpg') == -1:
                            AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[1].get_attribute('src')
                        elif AUX_JPG.find('.jpg') == -1:
                            AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[2].get_attribute('src')
                        if AUX_JPG.find('.jpg') != -1:
                            IMG = AUX_JPG
                        
                        ID = PRODUCTO.get_attribute('data-codprod')
                        DESCRIPCION = PRODUCTO.text
                        COLOR = NOMBRE_COLOR
                        PRECIO = PRODUCTO.text.split('\n')[1]
                        HREF = PRODUCTO.find_element_by_tag_name('a').get_attribute('href')
                        LISTA_PRODUCTOS.append([ID,
                                                DESCRIPCION,
                                                CATEGORIA[0],
                                                COLOR,
                                                url[0],
                                                PRECIO,
                                                HREF,
                                                IMG])
            
        else:

            for label_categoria in LABELS_CATEGORIA:
                #Lista con sub categorias
                SUB_CATEGORIAS.append([label_categoria.get_attribute('title').capitalize(),label_categoria.get_attribute('data-val')])
            #loop de sub_categorias
            for SUB in SUB_CATEGORIAS:
                #request de una sub_categoria : ejemplo (soutien)

                browser.get(SUB[1])
                #AUX_PALETA intenta ser el ultimo conjunto de la barra lateral izquierda (o sea "Color")
                try:                
                    AUX_PALETA = browser.find_element_by_xpath('//*[@id="catalogoFiltros"]').find_element_by_class_name('cnt').find_elements_by_class_name('blk')[-1]
                except:
                    continue
                #Si contiene 'Color' hicimos bien el trabajo, sino.. tendremos que revisar (si cambio el HTML)
                if 'Color' == AUX_PALETA.text:

                    #LOOP de AUX_PALETA, cada elemento tiene el color. 
                    PALETA = AUX_PALETA.find_elements_by_class_name('it')

                    PALETA_COLORES = [[i,i.get_attribute('data-val')] for i in PALETA]

                    #for COLOR_AUX in PALETA_COLORES:
                    for i in range(1,len(PALETA_COLORES)+1):
                        #ESTOY POR ACA DPS SEGUIR VIENDO
                        for X in [9,8,4,5,6]:
                            try:
                                #Clickear color
                                #Cada nombre en Capitalize() porque es minúscula
                                NOMBRE_COLOR = browser.find_element_by_css_selector(f'#catalogoFiltros > div > div:nth-child({X}) > div.cnt > div > label:nth-child({i})').get_attribute('data-val')    
                                #NOMBRE_COLOR = COLOR_AUX[1]
                                browser.find_element_by_css_selector(f'#catalogoFiltros > div > div:nth-child(9) > div.cnt > div > label:nth-child({i})').click()
                                break
                            except:
                                pass


                        time.sleep(1.5)


                        #requesst de la pagina actual
                        page = BeautifulSoup(browser.page_source,"html.parser")

                        #A VER SI FUNCIONA AHORA ESTA PORQUERIA
                        browser.get(browser.current_url)
                        ##scroll 
                        last_height = browser.execute_script("return document.body.scrollHeight")
                        while True:

                            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                            time.sleep(5.5)
                            try:
                                browser.execute_script('window.scrollTo(0, 1100);')
                                #browser.find_element_by_xpath('//*[@id="catalogoPaginado"]/button/span').click()
                                browser.execute_script('window.scrollTo(0, 1500);')
                                browser.find_element_by_id('catalogoPaginado').click()
                            except:
                                pass

                            new_height = browser.execute_script("return document.body.scrollHeight")
                            if new_height == last_height:
                                break
                            last_height = new_height

                        page = BeautifulSoup(browser.page_source,"html.parser")
                        #VER SI AL FINALIZAR EL SCROLL, SE PUDO MOSTRAR TODOS LOS PRODUCTOS
                        try:
                            if int(browser.find_element_by_id("catalogoPaginado").text.split()[1]) != int(browser.find_element_by_id("catalogoPaginado").text.split()[-1]):

                                print(browser.find_element_by_id("catalogoPaginado").text)
                                browser.find_element_by_xpath('//*[@id="catalogoPaginado"]/button').click()
                        except:
                            pass

                        #TODOS LOS PRODUCTOS
                        DIV_PRODUCTOS = browser.find_element_by_xpath('//*[@id="catalogoProductos"]').find_elements_by_class_name('it')

                        for PRODUCTO in DIV_PRODUCTOS:
                            #EXCLUIR LAS IMAGENES PNG(NORMALMENTE SON ICONOS)
                            AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[0].get_attribute('src')
                            if AUX_JPG.find('.jpg') == -1:
                                AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[1].get_attribute('src')
                            elif AUX_JPG.find('.jpg') == -1:
                                AUX_JPG = PRODUCTO.find_element_by_tag_name('a').find_elements_by_tag_name('img')[2].get_attribute('src')
                            if AUX_JPG.find('.jpg') != -1:
                                IMG = AUX_JPG

                            ID = PRODUCTO.get_attribute('data-codprod')
                            DESCRIPCION = PRODUCTO.text
                            COLOR = NOMBRE_COLOR
                            PRECIO = PRODUCTO.text.split('\n')[1]
                            HREF = PRODUCTO.find_element_by_tag_name('a').get_attribute('href')
                            LISTA_PRODUCTOS.append([ID,
                                                    DESCRIPCION,
                                                    SUB[0],
                                                    COLOR,
                                                    url[0],
                                                    PRECIO,
                                                    HREF,
                                                    IMG])
                        browser.get(SUB[1])


# In[11]:


dfCocot = pd.DataFrame(LISTA_PRODUCTOS)


# In[12]:


dfCocot.rename(columns={0:'codigo'},inplace=True)
dfCocot.rename(columns={1:'descripcion'},inplace=True)
dfCocot.rename(columns={2:'tipo'},inplace=True)
dfCocot.rename(columns={3:'color'},inplace=True)
dfCocot.rename(columns={4:'sexo'},inplace=True)
dfCocot.rename(columns={5:'precio'},inplace=True)
dfCocot.rename(columns={6:'url_producto'},inplace=True)
dfCocot.rename(columns={7:'img_producto'},inplace=True)


# In[14]:


dfCocot['DESC'] = dfCocot['descripcion'].str.capitalize().apply(lambda x : x.split('\n')[0].split(' - ')[0])


# In[15]:


dfCocot['color'] = dfCocot['color'].str.capitalize()


# In[16]:


dfCocot['fecha'] = fecha


# In[17]:


dfCocot['origen'] = 'COCOT UY'
dfCocot['marca'] = 'Cocot'

browser.quit()
if len(dfCocot.drop_duplicates()) == len(dfCocot.dropna()) == len(dfCocot) == True:
    print(f'CIUDADO DUPLICADOS EN {scraper}')


# In[18]:


writer = ExcelWriter('/home/aa/cloudJ/JB/PRD/scrapper/Scripts/Uruguay/Salida/cocot'+str(fecha)+'.xlsx')
dfCocot.to_excel(writer,'Hoja1')
writer.save()


# In[20]:


end_ = datetime.datetime.now()


# In[21]:


print('Tiempo de ejecución '+scraper+': '+str(end_ - start_)[:-7])

# %%
#!jupyter nbconvert --to script 'Cocot_uy.ipynb'
# Out:
# [NbConvertApp] Converting notebook Cocot_uy.ipynb to script
# [NbConvertApp] Writing 15293 bytes to Cocot_uy.py
