# %%
import subprocess
import os
import signal

# %%
#while ESCOPETAZO == True:
while True:
    cmd = 'powershell "gps | where {$_.MainWindowTitle } | select Description, id'
    proc = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE)
    for line in proc.stdout:
        if line.decode().find('Excel') != -1:
            candidato = line.decode().split()[-1]
            os.kill(int(candidato), signal.SIGTERM)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1400a4800b8f> in <module>
#       3     cmd = 'powershell "gps | where {$_.MainWindowTitle } | select Description, id'
#       4     proc = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE)
# ----> 5     for line in proc.stdout:
#       6         if line.decode().find('Excel') != -1:
#       7             candidato = line.decode().split()[-1]
#
# KeyboardInterrupt:

# %%
ESCOPETAZO = False

file = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.txt", "w")

file.write(str(ESCOPETAZO))
file.close()

# %%
try:
    r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.txt", "b")
    ESCOPETAZO = bool(r.read())
    
except FileNotFoundError as FNF:
    print('No se encuentra el directorio')

except Exception as e:
    print(e)
# Out:
# Must have exactly one of create/read/write/append mode and at most one plus

# %%
ESCOPETAZO
# Out:
# True

# %%
ESCOPETAZO = True
while ESCOPETAZO == True:
    #Intento abrir el txt, si no lo encuentra, no hace nada(porque puede ser que no exista hasta que termine "RELEVAMIENTO_EXCEL.PY",
    #Entonces obviamos esa Exception. Pero si encuentra OTRA Exception, vamos a frenar la ejecución y mostraremos cual es.
    try:
        r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.txt", "r")
        ESCOPETAZO = bool(r.read())

    except FileNotFoundError as FNF:
        pass

    except Exception as e:
        print(e)
        raise

    print(ESCOPETAZO)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.txt", "r")
ESCOPETAZO = bool(r.read())
ESCOPETAZO
# Out:
# True

# %%
r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.txt", "r")
r.read()
# Out:
# 'False'

# %%
import pickle
r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.pkl", "wb")
r.write(ESCOPETAZO)
r.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-44a00b7187f1> in <module>
#       1 import pickle
#       2 r = open("C:/Users/jhernandez/Practica_python/scriptRelevamiento/ESCOPETAZO.pkl", "wb")
# ----> 3 r.write(ESCOPETAZO)
#       4 r.close()
#
# TypeError: a bytes-like object is required, not 'bool'

# %%
ESCOPETAZO=True

pickle.dump(ESCOPETAZO , open("ESCOPETAZO.pkl","wb"))

# %%
ESCOPETAZO = pickle.load(open("ESCOPETAZO.pkl", "rb"))

# %%
ESCOPETAZO
# Out:
# True
