# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import requests
from time import strftime
import datetime
import time
from pandas import ExcelWriter
import re
import pyodbc
import asyncio
from selenium.webdriver.common.action_chains import ActionChains
import numpy as np
import pdb
from ipywidgets import IntProgress
from IPython.display import display
import os
from IPython.display import clear_output
import json
from selenium.webdriver.support import expected_conditions

from sc_header import scrape_batch, scrape_url, aplanar_lista, createDriver, return_chunk, aplanar

# %%
start_ = datetime.datetime.now()
fecha = datetime.date.today()
hoy = fecha.strftime('%Y/%m/%d')

# %%
browser = createDriver()

# %%
browser.get("https://www.zaful.com/")

# %%
browser.execute_script('''
$('#js-changeCountry').mouseover();
document.getElementsByClassName('header-country-wrapper')[0].getElementsByTagName('a')[0].click();
document.getElementsByClassName('header-country-wrapper')[0].click();
document.querySelector("#js-changeCountry > div > div.header-country-wrapper > div > ul.hot-country-list > li:nth-child(1) > a").click();

document.getElementsByClassName('link-update-preferences logsss_event_cl')[0].click();

''')

# %%
dfLinks = pd.read_excel(f'Links_{str(fecha)}.xlsx')

dfLinks = return_chunk(dfLinks,4)

# %%
start_ = datetime.datetime.now()
items = []
for index,row in dfLinks.iterrows():
    
    try:
        browser.get(row['url'])
    except:
        browser.quit()
        time.sleep(1)
        browser = createDriver()
        continue
    
    productos = browser.find_elements_by_class_name('js_proList_item')
    urllist = []
    for inx,product in enumerate(productos):
        urllist.append([product.find_element_by_css_selector('.pr.imgWrap').find_element_by_tag_name('a').get_attribute('href'),inx])
    batch_size = 5
    
    url_chunks = [urllist[x:x+batch_size] for x in range(0, len(urllist), batch_size)]
    
    for url_chunk in url_chunks:
        
        items.append(scrape_batch(url_chunk,row['url']))
        
    
    try:
        df_save = pd.DataFrame(items)
        df_save.to_excel('zaful4.xlsx')
        
        file = open("zaful_chunk4.txt", "w")
        file.write( str(url_chunk) + os.linesep)
        file.close()
    except:
        print("Error al guardar")
        
end_ = datetime.datetime.now()
browser.quit()

# %%
file = open("zaful-4.txt", "w")
file.write(  os.linesep +f'ZAFUL_4 - {len(df)}' )
file.write(  os.linesep +f'CANTIDAD DE ITEMS - {len(df)}' )
file.write(  os.linesep +f'DURACION - {format(end_ - start_)[:-4]}' )
file.close()

# %%
new_list = aplanar(items)

# %%
df = pd.DataFrame(new_list)


df.rename(columns={0:'pos',
                  1:'id_producto',
                  2:'talle',
                  3:'color',
                  4:'sexo',
                  5:'tipo',
                  6:'sub_categoria',
                  7:'descripcion',
                  8:'precio_dto',
                  9:'precio_original',
                  10:'img',
                  11:'url',
                  12:'pagina_scraper'
                  },inplace=True)

# %%
df.to_excel(f'./Salida/zaful4-{fecha}.xlsx')

# %%
****abajo debug**

# %%
df = pd.read_excel('zaful4.xlsx')

# %%
def restore_items(restore):
    total_items = []
    for index,row in restore.iterrows():

        for fila in row:

            fila_aux = fila.replace('"','').replace("'",'').strip('[]').split('], [')
            for row_aux in fila_aux:
                
                final_append = row_aux.split(',')
                total_items.append(list(map(str.strip,final_append)))

    return total_items

# %%
a = restore_items(df)

# %%
#items = []
#for i in a:
#    if len(i) != 13:

# %%
items = [i for i in a if len(i) ==13]

# %%
df = pd.DataFrame(items)

# %%
df.rename(columns={0:'pos',
                  1:'id_producto',
                  2:'talle',
                  3:'color',
                  4:'sexo',
                  5:'tipo',
                  6:'sub_categoria',
                  7:'descripcion',
                  8:'precio_dto',
                  9:'precio_original',
                  10:'img',
                  11:'url',
                  12:'pagina_scraper'
                  },inplace=True)

# %%
file = open("zaful-4.txt", "w")
file.write(  os.linesep +f'ZAFUL_4 - {len(df)}' )
file.write(  os.linesep +f'CANTIDAD DE ITEMS - {len(df)}' )
file.write(  os.linesep +f'DURACION - FALLO' )
file.close()

# %%
df.to_excel(f'./Salida/zaful4-{datetime.date(2020,2,10)}.xlsx')

# %%
df
# Out:
#      pos id_producto        talle                 color      sexo      tipo  \
# 0      0   459636901           XS                Blanco     Mujer      Tops
# 1      0   459636902            S                Blanco     Mujer      Tops
# 2      0   459636903            M                Blanco     Mujer      Tops
# 3      0   459636904            L                Blanco     Mujer      Tops
# 4      1   458939701            S      Crema de Cristal     Mujer      Tops
# 5      1   458939702            M      Crema de Cristal     Mujer      Tops
# 6      1   458939703            L      Crema de Cristal     Mujer      Tops
# 7      2   458749301            S                Rosado     Mujer      Tops
# 8      2   458749302            M                Rosado     Mujer      Tops
# 9      2   458749303            L                Rosado     Mujer      Tops
# 10     2   458749304           XL                Rosado     Mujer      Tops
# 11     3   461399601            S            Multicolor     Mujer      Tops
# 12     3   461399602            M            Multicolor     Mujer      Tops
# 13     3   461399603            L            Multicolor     Mujer      Tops
# 14     4   457696801            S      Crema de Cristal     Mujer      Tops
# 15     4   457696802            M      Crema de Cristal     Mujer      Tops
# 16     4   457696803            L      Crema de Cristal     Mujer      Tops
# 17     4   457696804           XL      Crema de Cristal     Mujer      Tops
# 18     5   459698301            S            Vino Tinto     Mujer      Tops
# 19     5   459698302            M            Vino Tinto     Mujer      Tops
# 20     5   459698303            L            Vino Tinto     Mujer      Tops
# 21     5   459698304           XL            Vino Tinto     Mujer      Tops
# 22     6   458031301            S         Marrón Dorado     Mujer  Vestidos
# 23     6   458031302            M         Marrón Dorado     Mujer  Vestidos
# 24     6   458031303            L         Marrón Dorado     Mujer  Vestidos
# 25     6   458031304           XL         Marrón Dorado     Mujer  Vestidos
# 26     7   457274206            S            Azul Denim     Mujer      Tops
# 27     7   457274207            M            Azul Denim     Mujer      Tops
# 28     7   457274208            L            Azul Denim     Mujer      Tops
# 29     7   457274209           XL            Azul Denim     Mujer      Tops
# ...   ..         ...          ...                   ...       ...       ...
# 3543  50   280383803            L            Multicolor     Mujer      Tops
# 3544  51   299193101            S            Gris Claro     Mujer      Tops
# 3545  51   299193102            M            Gris Claro     Mujer      Tops
# 3546  51   299193103            L            Gris Claro     Mujer      Tops
# 3547  51   299193104           XL            Gris Claro     Mujer      Tops
# 3548  52   457196501            S                Blanco     Mujer      Tops
# 3549  52   457196502            M                Blanco     Mujer      Tops
# 3550  52   457196503            L                Blanco     Mujer      Tops
# 3551  52   457196504           XL                Blanco     Mujer      Tops
# 3552  53   283886603  Talla única          Multicolor A     Mujer      Tops
